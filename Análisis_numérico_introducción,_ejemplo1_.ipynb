# %% [markdown]
# <a href="https://colab.research.google.com/github/LeidyDaniela/AnalisisNumerico2020_2/blob/master/An%C3%A1lisis_num%C3%A9rico_introducci%C3%B3n%2C_ejemplo1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

x = np.arange(0, 9 * np.pi, 0.2)
y = np.sin(x)

# %%
plt.plot(x, y)
